# %%
import pandas as pd
import numpy as np

df = pd.read_csv('cleaned_data.csv')
df = df.drop(df.columns[[0]], axis=1)
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0        149190     55629189        Caucasian  Female  [10-20)
# 1         64410     86047875  AfricanAmerican  Female  [20-30)
# 2        500364     82442376        Caucasian    Male  [30-40)
# 3         16680     42519267        Caucasian    Male  [40-50)
# 4         35754     82637451        Caucasian    Male  [50-60)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  1                         1                    7
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  2                         1                    2
#
#    time_in_hospital  num_lab_procedures  ...  citoglipton  insulin  \
# 0                 3                  59  ...           No       Up
# 1                 2                  11  ...           No       No
# 2                 2                  44  ...           No       Up
# 3                 1                  51  ...           No   Steady
# 4                 3                  31  ...           No   Steady
#
#    glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 0                   No                   No                        No
# 1                   No                   No                        No
# 2                   No                   No                        No
# 3                   No                   No                        No
# 4                   No                   No                        No
#
#   metformin-rosiglitazone metformin-pioglitazone change  diabetesMed  \
# 0                      No                     No     Ch          Yes
# 1                      No                     No     No          Yes
# 2                      No                     No     Ch          Yes
# 3                      No                     No     Ch          Yes
# 4                      No                     No     No          Yes
#
#   readmitted
# 0          1
# 1          0
# 2          0
# 3          0
# 4          1
#
# [5 rows x 47 columns]

# %%
'Number of patients in dataset is {:,}'.format(df['patient_nbr'].nunique())
# Out:
# 'Number of patients in dataset is 68,630'

# %%
'Number of records in dataset is {:,}'.format(len(df))
# Out:
# 'Number of records in dataset is 98,053'

# %% [markdown]
# ## Pairwise Scatter Plots

# %%
import seaborn as sns
sns.pairplot(df);

# %% [markdown]
# ## Correlation Matrix

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col1 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col3 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col4 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col6 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col7 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col8 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col9 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col10 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col11 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col12 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row0_col13 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col0 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col2 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col3 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col4 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col5 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col6 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col7 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col8 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col9 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col10 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col11 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col12 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row1_col13 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col1 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col4 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col5 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col6 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col7 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col8 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col9 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col10 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col11 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col12 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row2_col13 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col1 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col2 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col4 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col5 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col6 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col7 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col8 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col9 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col10 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col11 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col12 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row3_col13 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row4_col0 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row4_col1 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row4_col2 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_5cf031b0_0d73_11ea_b0be_4889e7cd0c43row4_col3 {
#             background-color:  #6a8bef;
#             colo

# %% [markdown]
# ## HbAIc

# %%
# Using A1Cresult as signaling whether an HbA1c test was performed
df['A1Cresult'].value_counts()
# Out:
# None    81860
# >8       7631
# Norm     4854
# >7       3708
# Name: A1Cresult, dtype: int64

# %%
# Using 'change' as signaling whether diabetes med changed
df['change'].value_counts()
# Out:
# No    52774
# Ch    45279
# Name: change, dtype: int64

# %%
df_egroups = df[['A1Cresult', 'change']]

# %%
h =df_egroups.groupby('A1Cresult').count()
h
# Out:
#            change
# A1Cresult
# >7           3708
# >8           7631
# None        81860
# Norm         4854

# %%
pd.crosstab(df_egroups.A1Cresult, df_egroups.change)
# Out:
# change        Ch     No
# A1Cresult
# >7          1885   1823
# >8          5052   2579
# None       36186  45674
# Norm        2156   2698

# %%
# view distribution of med change status across different a1c results. 
pd.crosstab(df_egroups.A1Cresult, df_egroups.change).apply(lambda r: r/r.sum(), axis=0)
## majority of those with a change had no testing, but most patients didn't get testing
# Out:
# change           Ch        No
# A1Cresult
# >7         0.041631  0.034544
# >8         0.111575  0.048869
# None       0.799178  0.865464
# Norm       0.047616  0.051124

# %%
# view distribution of med change stratified by a1c results
pd.crosstab(df_egroups.A1Cresult, df_egroups.change).apply(lambda r: r/r.sum(), axis=1)
## a larger share of patients with high a1c results had med changes than those with non-elevated a1c results
# Out:
# change           Ch        No
# A1Cresult
# >7         0.508360  0.491640
# >8         0.662036  0.337964
# None       0.442047  0.557953
# Norm       0.444170  0.555830

# %%
df2 = df.copy()

# %%
def label_encounter (row):
    if row['A1Cresult'] == 'None': return 'None'
    if row['A1Cresult'] == 'Norm': return 'Normal'
    if row['A1Cresult'] == '>8' and row['change']=='No': return 'High Medical No Change'
    if row['A1Cresult'] == '>8' and row['change']=='Ch': return 'High Medical Change'
    return 'Other'

# %%
df2['encounter_group'] =df2.apply (lambda row: label_encounter (row),axis=1)

# %%
# seeing who the "Other" cases are...the paper grouping didn't consider when >7, but less than 8.
df2[['A1Cresult','change']][df2.encounter_group == 'Other'].sample(2)
# Out:
#       A1Cresult change
# 69200        >7     Ch
# 923          >7     Ch

# %%
# another view of counts by encounter groups
df2['encounter_group'].value_counts()
# Out:
# None                      81860
# High Medical Change        5052
# Normal                     4854
# Other                      3708
# High Medical No Change     2579
# Name: encounter_group, dtype: int64

# %%
from matplotlib import pyplot as plt

df3 = df2['encounter_group'].value_counts()
df3.plot(kind = 'bar')
plt.xlabel('HbA1C Test')
plt.ylabel('Population')
plt.savefig('HbA1cResults.jpg')

# %% [markdown]
# ### Label the Diagnosis

# %%
def label_diagnosis (i):
    i= i.strip("V").strip("E")
#     i = float(i)
    if i in list(range(390,495)) or i=='785': return 'Circulatory'
    elif i in list(range(460,519)) or i=='786': return 'Respiratory'
    elif i in list(range(520,579)) or i=='787': return 'Digestive'
    elif float(i)>=250 and float(i)<251: return 'Diabetes'
    elif i in list(range(800,999)): return 'Injury'
    elif i in list(range(710,739)): return 'Musculoskeletal'
    elif i in list(range(580,629)) or i=='788': return 'Genitourinary'
    elif i in list(range(140,239)): return 'Neoplasms'
    else: return 'Other'

# %%
df2['diag_1'] =df2['diag_1'].apply(label_diagnosis)

# %%
print(df2['diag_1'].unique())
# Out:
# ['Other' 'Diabetes' 'Respiratory' 'Digestive' 'Genitourinary'
#  'Circulatory']

# %% [markdown]
# ## HbA1c Effects on Medication Number

# %%
import seaborn as sns

# For all patients
sns.boxplot(x=df2['encounter_group'],y=df2['num_medications'])

# %%
## For patients whose primary diagnosis was Diabetes
diabetes = df2[df2['diag_1']=='Diabetes']
sns.boxplot(x=diabetes['encounter_group'],y=diabetes['num_medications'])

# %% [markdown]
# ## Hospital Readmission Ratios vs. HbA1c Results

# %%
## For patients whose primary diagnosis was Diabetes
d2 = pd.DataFrame(diabetes.groupby(['encounter_group'])['readmitted'].sum())
d2.columns = ['num_readmitted']
d2.reset_index(inplace=True)
print(d2)
# Out:
#           encounter_group  num_readmitted
# 0     High Medical Change             511
# 1  High Medical No Change             240
# 2                    None            3091
# 3                  Normal             214
# 4                   Other             145

# %%
d3 = pd.DataFrame(diabetes['encounter_group'].value_counts())
d3.reset_index(inplace=True)
d3.columns = ['encounter_group','num_group']
print(d3)
# Out:
#           encounter_group  num_group
# 0                    None       5561
# 1     High Medical Change       1168
# 2  High Medical No Change        509
# 3                  Normal        444
# 4                   Other        283

# %%
d4 = d2.merge(d3, on='encounter_group')
d4['readmission_ratio']= d4['num_readmitted'] / d4['num_group']

print(d4)
d4.plot(kind='bar', x='encounter_group', y='readmission_ratio',legend=False)
plt.xlabel('HbA1C Test Result')
plt.ylabel('Readmission Ratio')
# Out:
#           encounter_group  num_readmitted  num_group  readmission_ratio
# 0     High Medical Change             511       1168           0.437500
# 1  High Medical No Change             240        509           0.471513
# 2                    None            3091       5561           0.555835
# 3                  Normal             214        444           0.481982
# 4                   Other             145        283           0.512367
# Text(0, 0.5, 'Readmission Ratio')

# %% [markdown]
# ## Summary
#
# * Diabetic patients are primarily diagnosed as serval diseases. Most of the diagnoses are performed without HbA1c test. However, HbA1c test is a very improtant parameter for efficient treatment of diabetic patients.
#
# * Using the mdication numbers of normal HbA1c result as baseline, the high H1bAc test with medication change results in an increase medication number. However, that without medication change reduces medication number.
#
# * The relationship between the readmission ratio and the HbA1c measurement signicantly depends on the primary diagnosis. Our analyses indicate whether medication change of high HbA1c result is effective for different primary diagnosis.
